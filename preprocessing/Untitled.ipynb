# %%
from pyspark.sql import DataFrame, Row, SparkSession
import os

# %%
def get_spark(name="Recsys", cores=2, local_dir="/tmp/spark-temp") -> SparkSession:
    # make sure the local_dir exists in your file system
    # default settings work for linux
    spark = (SparkSession
             .builder
             .appName(name)
             .master("local[{}]".format(cores))
             .config("spark.memory.offHeap.enabled", True)
             .config("spark.memory.offHeap.size", "16g")
             .config("spark.local.dir", local_dir)
             .getOrCreate())

    spark.sparkContext.setCheckpointDir(os.path.join(local_dir, "chkpts/"))
    return spark

# %%
spark = get_spark(cores=4)

# %%
sc = spark.sparkContext

# %%
df = spark.read.json("../../yelp_dataset/review.json")

# %%
df.printSchema()

# %%
df = df.select("business_id", "cool", "date", "funny", "review_id", "stars", "useful", "user_id")

# %%
df.count()

# %%
df.coalesce(1).write.option("header", "true").csv("ratings.csv")

# %%
import pandas as pd

# %%
df = pd.read_csv("./ratings.csv")

# %%
user_count = df.groupby("user_id")["review_id"].count().reset_index()

# %%
filtered_user = user_count[user_count.review_id >= 10]["user_id"]

# %%
merged_df = df.merge(filtered_user, on="user_id")

# %%
d

# %% [markdown]
# # Business meta data

# %%
spark = get_spark(cores=4)

# %%
df_meta.printSchema()
# Out:
# root
#  |-- address: string (nullable = true)
#  |-- attributes: struct (nullable = true)
#  |    |-- AcceptsInsurance: string (nullable = true)
#  |    |-- AgesAllowed: string (nullable = true)
#  |    |-- Alcohol: string (nullable = true)
#  |    |-- Ambience: string (nullable = true)
#  |    |-- BYOB: string (nullable = true)
#  |    |-- BYOBCorkage: string (nullable = true)
#  |    |-- BestNights: string (nullable = true)
#  |    |-- BikeParking: string (nullable = true)
#  |    |-- BusinessAcceptsBitcoin: string (nullable = true)
#  |    |-- BusinessAcceptsCreditCards: string (nullable = true)
#  |    |-- BusinessParking: string (nullable = true)
#  |    |-- ByAppointmentOnly: string (nullable = true)
#  |    |-- Caters: string (nullable = true)
#  |    |-- CoatCheck: string (nullable = true)
#  |    |-- Corkage: string (nullable = true)
#  |    |-- DietaryRestrictions: string (nullable = true)
#  |    |-- DogsAllowed: string (nullable = true)
#  |    |-- DriveThru: string (nullable = true)
#  |    |-- GoodForDancing: string (nullable = true)
#  |    |-- GoodForKids: string (nullable = true)
#  |    |-- GoodForMeal: string (nullable = true)
#  |    |-- HairSpecializesIn: string (nullable = true)
#  |    |-- HappyHour: string (nullable = true)
#  |    |-- HasTV: string (nullable = true)
#  |    |-- Music: string (nullable = true)
#  |    |-- NoiseLevel: string (nullable = true)
#  |    |-- Open24Hours: string (nullable = true)
#  |    |-- OutdoorSeating: string (nullable = true)
#  |    |-- RestaurantsAttire: string (nullable = true)
#  |    |-- RestaurantsCounterService: string (nullable = true)
#  |    |-- RestaurantsDelivery: string (nullable = true)
#  |    |-- RestaurantsGoodForGroups: string (nullable = true)
#  |    |-- RestaurantsPriceRange2: string (nullable = true)
#  |    |-- RestaurantsReservations: string (nullable = true)
#  |    |-- RestaurantsTableService: string (nullable = true)
#  |    |-- RestaurantsTakeOut: string (nullable = true)
#  |    |-- Smoking: string (nullable = true)
#  |    |-- WheelchairAccessible: string (nullable = true)
#  |    |-- WiFi: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- categories: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- hours: struct (nullable = true)
#  |    |-- Friday: string (nullable = true)
#  |    |-- Monday: string (nullable = true)
#  |    |-- Saturday: string (nullable = true)
#  |    |-- Sunday: string (nullable = true)
#  |    |-- Thursday: string (nullable = true)
#  |    |-- Tuesday: string (nullable = true)
#  |    |-- Wednesday: string (nullable = true)
#  |-- is_open: long (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- name: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- state: string (nullable = true)

# %%
df_meta = spark.read.json("../../yelp_dataset/business.json")

# %%
df_selected_meta = df_meta.select(["business_id", "categories", "city", "name", "review_count", "stars", "state"])

# %%
df_selected_meta.show()
# Out:
# +--------------------+--------------------+------------------+--------------------+------------+-----+-----+
# |         business_id|          categories|              city|                name|review_count|stars|state|
# +--------------------+--------------------+------------------+--------------------+------------+-----+-----+
# |1SWheh84yJXfytovI...|   Golf, Active Life|           Phoenix|Arizona Biltmore ...|           5|  3.0|   AZ|
# |QXAEGFB4oINsVuTFx...|Specialty Food, R...|       Mississauga|Emerald Chinese R...|         128|  2.5|   ON|
# |gnKjwL_1w79qoiV3I...|Sushi Bars, Resta...|         Charlotte|Musashi Japanese ...|         170|  4.0|   NC|
# |xvX2CttrVhyG2z1dF...|Insurance, Financ...|          Goodyear|Farmers Insurance...|           3|  5.0|   AZ|
# |HhyxOkGAM07SRYtlQ...|Plumbing, Shoppin...|         Charlotte| Queen City Plumbing|           4|  4.0|   NC|
# |68dUKd8_8liJ7in4a...|Shipping Centers,...|       Mississauga|       The UPS Store|           3|  2.5|   ON|
# |5JucpCfHZltJh5r1J...|Beauty & Spas, Ha...|           Calgary|    Edgeworxx Studio|           7|  3.5|   AB|
# |gbQN7vr_caG_A1ugS...|Hair Salons, Hair...|         Las Vegas|           Supercuts|           3|  3.5|   NV|
# |Y6iyemLX_oylRpnr3...|Nail Salons, Beau...|          Glendale|Vita Bella Fine D...|           8|  5.0|   AZ|
# |4GBVPIYRvzGh4K4Tk...|Beauty & Spas, Na...|     Fairview Park| Options Salon & Spa|           8|  4.5|   OH|
# |fcXOEZdXYeZqnQ3lG...|Local Services, P...|           Calgary|Nucleus Informati...|           5|  2.0|   AB|
# |1Dfx3zM-rW4n-31Ke...|Restaurants, Brea...|           Phoenix|           Taco Bell|          18|  3.0|   AZ|
# |5t3KVdMnFgAYmSl1w...|Bars, Nightlife, ...|       Mooresville|The Kilted Buffal...|           9|  3.5|   NC|
# |fweCYi8FmbJXHCqLn...|Italian, Restaura...|Mentor-on-the-Lake|       Marco's Pizza|          16|  4.0|   OH|
# |-K4gAv8_vjx8-2Bxk...|      Bakeries, Food|        Willoughby|          Baby Cakes|           7|  3.0|   OH|
# |A98xW4qb7vOTguggH...|Fitness & Instruc...|     Richmond Hill|   Hot Yoga Wellness|           4|  4.0|   ON|
# |giC3pVVFxCRR89rAp...|Hair Stylists, Be...|        Scottsdale|          Knot Salon|           5|  5.0|   AZ|
# |PZ-LZzSlhSe9utkQY...|Restaurants, Italian|         Las Vegas|Carluccio's Tivol...|          40|  4.0|   NV|
# |nh_kQ16QAoXWwqZ05...|Event Planning & ...|         Las Vegas|Myron Hensel Phot...|          21|  5.0|   NV|
# |zSpQmEBvRe3IhTUlM...|Trainers, Health ...|           Toronto|  Totum Life Science|          23|  4.0|   ON|
# +--------------------+--------------------+------------------+--------------------+------------+-----+-----+
# only showing top 20 rows

# %%
import requests
from urllib.error import HTTPError
from urllib.parse import quote
from urllib.parse import urlencode

def request(host, path, api_key, url_params=None):
    """Given your API_KEY, send a GET request to the API.
    Args:
        host (str): The domain host of the API.
        path (str): The path of the API after the domain.
        API_KEY (str): Your API Key.
        url_params (dict): An optional set of query parameters in the request.
    Returns:
        dict: The JSON response from the request.
    Raises:
        HTTPError: An error occurs from the HTTP request.
    """
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }

    print(u'Querying {0} ...'.format(url))

    response = requests.request('GET', url, headers=headers, params=url_params)

    return response.json()

# %%
key="HwkCu8bbu6Lv43rqp__sk9Z36evS2vSApDUzNSPHb9fguOLzX7G8bOMI2GFZOuVee9mlkY1y-0xif98nQgVTRGcTj9VTjG-BzxQDrdhKrZRbP0fsFXwy7zzCVKHZXXYx"
cat_dict = request(host="https://api.yelp.com/v3", path="/categories", api_key=key)["categories"]
# Out:
# Querying https://api.yelp.com/v3/categories ...

# %%
alias_to_title = {cat["alias"]: cat["title"] for cat in cat_dict}

# %%
import networkx as nx

# %%
G = nx.DiGraph()
for cat in cat_dict:
    parent = cat["parent_aliases"]
    parent_title = alias_to_title[parent[0]] if parent else None
    
    if parent_title:
        G.add_edge(parent_title, cat["title"])

# %%
zero_in_degree_nodes = filter(lambda tup: tup[1] == 0, G.in_degree(G.node()))
top_categories = list(map(lambda tup: tup[0], zero_in_degree_nodes))

# %%
top_categories
# Out:
# ['Local Services',
#  'Food',
#  'Professional Services',
#  'Beauty & Spas',
#  'Health & Medical',
#  'Shopping',
#  'Education',
#  'Nightlife',
#  'Restaurants',
#  'Religious Organizations',
#  'Automotive',
#  'Hotels & Travel',
#  'Active Life',
#  'Pets',
#  'Arts & Entertainment',
#  'Home Services',
#  'Public Services & Government',
#  'Event Planning & Services',
#  'Financial Services',
#  'Bicycles',
#  'Local Flavor',
#  'Mass Media']

# %%
with open("../../yelp_dataset/top_categories.json", "w") as f:
    f.write(json.dumps(top_categories))

# %%
def find_top_category(str_cats):
    not_found = "NotFound"
    if not str_cats: return not_found
    
    cats = set(map(lambda x: x.strip(), str_cats.split(",")))
    intersections = cats.intersection(set(top_categories))
    
    return list(intersections)[0] if intersections else not_found

# %%
find_top_category("Golf, Active Life")
# Out:
# 'Active Life'

# %%
from pyspark.sql.functions import udf, col
from pyspark.sql.types import StringType

find_top_cat_udf = udf(find_top_category, StringType())

# %%
df_filtered = df_selected_meta.withColumn("top_category", find_top_cat_udf("categories"))

# %%
import pyspark.sql.functions as F
df_filtered.filter(col("top_category") == "NotFound").select("review_count", "business_id").withColumn("rank", dense_rank().over(Window.orderBy(desc("review_count")))).show(truncate=False)
# Out:
# +------------+----------------------+----+
# |review_count|business_id           |rank|
# +------------+----------------------+----+
# |51          |KPK0Tsr7_mIZJmuVIMIXGg|1   |
# |22          |KE2x93Tltbj9eQbaBqgY8g|2   |
# |19          |l1gJuDUXH3erEKKuXMELkA|3   |
# |17          |yo8TQab_kYgAZm_DJkRjfA|4   |
# |17          |OcZvEbjudxPdlRdmFx-QSA|4   |
# |15          |9Jk2NZv58bYmoxuuKUD9TQ|5   |
# |15          |I0C8HvraosuTo2lRPjOedA|5   |
# |14          |T38PudlpzBl8Pu46WmR5KA|6   |
# |14          |h9B-VivFS_8BRX7MKF1bJw|6   |
# |14          |2EcEsmpxAOXBBtH9kGVSaA|6   |
# |13          |keYMjcRYI6YTR8lmhgvjPQ|7   |
# |13          |rS2V2_n5pPgBUJPHFfm9Pw|7   |
# |12          |yGpVxscoFR0Z51ERu3dz2w|8   |
# |12          |sR_od2KqmI4A6rFx-wLb0A|8   |
# |12          |I5tXvU7xf4Og26RIXdclTw|8   |
# |11          |VUrBExjDoBpNURe_tfXEXw|9   |
# |11          |BrkFoWcPapSxH1jvia0_FA|9   |
# |11          |8E4axw7ZyXtsie2F1JNnpQ|9   |
# |10          |nxQE3EkPt63yNwDZr8dDDA|10  |
# |10          |sWfRvsDIt6uqNE1ByZQCxQ|10  |
# +------------+----------------------+----+
# only showing top 20 rows

# %%
df.filter(col("business_id") == "xOR85RicYj642O3_iJ7hgg").show()
# Out:
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |         business_id|cool|               date|funny|           review_id|stars|                text|useful|             user_id|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |xOR85RicYj642O3_i...|   0|2018-05-23 02:25:30|    0|CCmarUnBTnaOGh3yP...|  5.0|Andrew is a class...|     0|5qYWXXVRHM2hP7za5...|
# |xOR85RicYj642O3_i...|   0|2018-06-18 21:35:26|    0|xK4jt3ViCHohazNaP...|  5.0|Couldn't have had...|     0|g0TXe-0RY7JszAefl...|
# |xOR85RicYj642O3_i...|   0|2015-05-20 04:50:39|    1|cBLClxXwaADbYVVLE...|  1.0|Andrew did not ac...|     2|KFOYvo_F3aQF2uReb...|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+

# %%
df_null_cats = df_selected_meta.filter(col("categories").isNull()).select("business_id").collect()

# %%
df_null_cats = list(map(lambda r: r.business_id, df_null_cats))

# %%
df_null_cats
# Out:
# ['xOR85RicYj642O3_iJ7hgg',
#  'tWvep1usNNI3NYkoRbSb7g',
#  'llG2YxnevtFhW7LVa4QJXQ',
#  'zi2CV7isWyGRxVXJxdDQXg',
#  'oyPZZX2fQYpSBHk25tL26A',
#  'AEpvBhxrmHJud4UgvF2yWw',
#  '3egQ7WCM-zQn9SXEBXbsDA',
#  'AMhPJSh9S6Qz9Q3DuwPgtA',
#  'KnAV3ZhOWWNhqnvqIkxYOg',
#  'TyQ5wC1XolgYclbGoga_gA',
#  'm_7y1JLy-g4IDKn7wmWRtw',
#  'A28Cy-EJQbSoljM8os75_Q',
#  'yVGggY8DCt2MIkdfUP7Bhg',
#  'ThEUWXkgLbi5RiulgybrTA',
#  'pLMdNuomFNGNt88-MQjCTA',
#  'zdKWo-B3xcYevFoXS1OU9g',
#  'ER56uNZR258-DXFYLNIGRA',
#  'Pjmnta--nDOS6jHCDhsLGg',
#  '851BjaHB_fBWxTa6NWa1eQ',
#  'yo8TQab_kYgAZm_DJkRjfA',
#  'K523J2fkBWEIZD8MV1Awiw',
#  'xI_nnDMMF6TeUe9ISRGP2A',
#  'ql8_D-3jsGvzWxrLpv8QpA',
#  'QvVRV-XkZeWWmRyIO1Oq6g',
#  'MPkPxObPAEgVhhIhAcw7UA',
#  'KE2x93Tltbj9eQbaBqgY8g',
#  '7Zwh96kpZWloOnVouI0O0w',
#  'CFWoroWZPq7p3pnjxZWpug',
#  '-qboK8vzF3vwFM5heO70mQ',
#  'ZDOW_bRF6wtCNwkakMF-lA',
#  'dVXPpWBka9AT2dHNnuPp6g',
#  'pu0rpDtMPltl8Q-1Ad8hOQ',
#  'BeGJJZaQbGVYEZo5rJ8P2A',
#  '0dN_UGbAW1Ei0wRocUfWGw',
#  'rWsoiLQeFy-RCdYtQvH-JA',
#  'SoiXeBUyWZQsBvjBMqkjZQ',
#  'nxQE3EkPt63yNwDZr8dDDA',
#  'Ui21y_IBb3LIyDNGwyVBQQ',
#  'ga5_K7TQaVYjE1xVAKfI7g',
#  'ZxGhSdirf0_NmxS8L-BZ5g',
#  'pGZyz-l87hJt9kJsTM9Y2g',
#  'um0brvgJQ_k0bfYQ4S6FpA',
#  'uqkqTck9OS-yi_nzjpE1zQ',
#  'VUrBExjDoBpNURe_tfXEXw',
#  'GkdPyDsb8y0xfArDam0Ifw',
#  'CuPewu9leQKom5fxuemJkg',
#  'UUnLZ67ItbuypMdY6FpFEg',
#  '_4423aHxT7EQ3peGS-7uVg',
#  'tSRQA8wXH6fIHGDpV0j99Q',
#  'sWfRvsDIt6uqNE1ByZQCxQ',
#  'JSmcDBsshrF1gIeEpwmRkw',
#  'w8StGT9HoK3EHqnVgdI7ew',
#  'SSK2eUPdv23DmzyNEMTMIA',
#  '0vcDlNQI1VQ4PTzRwOOuHw',
#  '67fzmWD3TbwrGDZ-Xp6VSA',
#  'eefO7_-EYi7f4V9RwckKgg',
#  'VKWfL7_JkKuN4oO-zrU-Xw',
#  'R9Z2ZILvTgYBbF-WNO19JA',
#  'BrkFoWcPapSxH1jvia0_FA',
#  'zJXQH5j6J8OKBVJIjZ428Q',
#  'TXjO2gUWZeCIM2b6x2W7FA',
#  'dSIuM0EQR0N7dBhlNLEk7w',
#  'OtWxYEO6i5VxtyBwS3b4MQ',
#  'oMaffgz2Sz6jeGzpHM9EGg',
#  'Y76jGd_f889OT4oz9pLgZA',
#  'nscblh2G_TqFjw3tZVLWUw',
#  'K0i8UwxEYFv8mqHl7jAkrg',
#  'XwoyRi5OQ4WQ_MwS1nNIbQ',
#  'GcEHmP-0kBBXtaGgRH6jyg',
#  'uOxzwcb_BkyNdpclAmFe9Q',
#  'eB9fqLu2etn1ukT1dIehnw',
#  'lzBSrKaxBqaUlmqJl5lKcA',
#  'iblPKi9bMDq6dEAU2ZPG9g',
#  'iMmC23aDqDfeof1YqAUMww',
#  'rN0l7FdxMqCZ5H2vDn-TyA',
#  '1rgJ-WYCEWM-RIyQN6AteA',
#  's10JWnGTd8TuEmkkPM_GJg',
#  'CL9XyNcvlNxt_lBbv8rcAQ',
#  '4YI_gJQuW-8d_o2xvflJxA',
#  'le-zKTxq19KN9Lz5UTnZ1g',
#  'ZU3OJFx7BHYuXib_AADiDQ',
#  'mOSvI-xpukCF5w01YawP5A',
#  'Xmsk8PMD9HsdiGPnHdVJ6w',
#  'P7QBF3lx0K9e6UgsQPg6lA',
#  'h_QgYTWQsige3pbLhl7F5w',
#  'KLF6afdlDIpPWGXWNrDp8w',
#  'YBXu5_McEzHGmHMPGBGRww',
#  '_aT3ug_pjBk-M4PBrcMYxA',
#  'aGKMYhUJZBimTmvvtSNxiA',
#  'dvlHvfogMkW_9eA0_4NAOw',
#  'GPeDmsmRgnrqMVdB52nuCw',
#  'CCUdztad73BWsGMetfbnRw',
#  'zxg3vChBI__R6q7ACtyokw',
#  '82YJYBTOx1z_tSRlOBL6eA',
#  'Lm-3-VnMbCYjB8d1hRIM8w',
#  'vNFA7L90qUlzfyKW-NEwZw',
#  '_ggoKDoEAXlbvFyp35ZB5g',
#  'JIqnZP04n9zKExGn4U8q7A',
#  'CFGQj_FuyhPfHAjkZYJeMg',
#  'EcjTzrgfTPfyVxbpyRiYQg',
#  'ryB1G6OCWUQhwzgZUiu_cw',
#  'N4SGtb4AWCn3kWoDthEruA',
#  '_gw6iXnPugGZ2NTu1Q3xKg',
#  'tkjfvkhz2pkXTcJ8ElxTLw',
#  'FmzNtCCPMKtjLdEopH_tVg',
#  '531PmfI6GEj9VMfgV07aqw',
#  'FlTOLJrSaPQqO2lx6Q1DTA',
#  'fc-UyqUIy9BDmI9wlQBUWg',
#  'pAzJqfPnecnqPDMG-_Htbg',
#  'SILdC7-ez6fAae7nlkpVSA',
#  'QLEpr_m3C_W5ASXRmfFCng',
#  'H3zUFXnG3IZDffNVRbu4hQ',
#  '_l7tg4uhYkiei7wFKAMP3Q',
#  'Bp2DjjBeVnt-qPs_XOzdSA',
#  'FC2jzYUqDNfQXQG0SiAqhQ',
#  '9kw4lUyO2VhGKDvPg4J50w',
#  'modnHkJKGUZL9XqaB9D0cA',
#  'jozuj1ySOk7DPs7OJloj3A',
#  'ry4kg-DZIDNfzqvmyjd9mw',
#  'gErOxDh3gMecoEmG5hYblA',
#  '-alO0UiSDdiNHKxbdShsKw',
#  '90O7AQ-qOkHKWxYkHZ-eHA',
#  'Ez1NHUBVDYrAUB-VtZImtQ',
#  'Xli12DG5UKWqcT_0rSWV8w',
#  'B0tuAmCiBRm66bqKV5IehA',
#  'JMRY7UHUHrWrWhB7IY9Lcg',
#  'bgRN6iUfQ8zLMTtTSkFzVw',
#  'VKMl433OFg1lolKdHgX5Wg',
#  'vxSN48M97AA08CcEbeJAxg',
#  '-dr5L_FCXNxtbA5h8_JZGQ',
#  'ndF0QBqlkrQ0V3ngU_bgWA',
#  '7imKrnoYDHrKFFF3wKGYRQ',
#  'SwfwEv0CiYljmmWgNzHZXA',
#  'KoVaIM-azBd6oMJsvCTq_A',
#  'L6jQwWQm7MdDPR5evEeihQ',
#  'th3jABvw-LnWAIRqb6JkGg',
#  'RzLXK-FJQw0SVZ1GjkLzJA',
#  'WgzPqIyQrYcFxUNvemXoHw',
#  'kPiK9DDo538b2LC7ZRZTMg',
#  'EDsYyD16AuF5CQof0VsoCw',
#  'of6i2DwNrxMpUc9L_BvvLQ',
#  'VBGdIHc0Ueuk4iG98UGR7g',
#  'yBuHAT4MwrVWgBQA_nzKIQ',
#  'wYanydP3E4AYhkapXz2NxA',
#  'j0-o3lZW9rTlz1zUFi05CA',
#  '3ZKIglyttXXhGhUQqE1ROA',
#  'f1ClZiQfbJSYgqklnGFCeQ',
#  'ABh8x8Dpt_5PtyC4he358g',
#  'gLy2OhF_RFvktjFYTleshA',
#  '8eHUD8OBe2nXaLKV68K0Rw',
#  '2OHASStsgre0tOBK5kXX6Q',
#  'yxTkyYEWzfsPbD58_Zblig',
#  'HfZhAgUCGUoHylRxPlNaZg',
#  'keYMjcRYI6YTR8lmhgvjPQ',
#  'UZB655eElyCUxvA7daeTwg',
#  'yQc0gEosjhBmf2Kn6YIx_Q',
#  'wQh4rS5HNL3fOTQMCfp-sQ',
#  'Us14EY4DXvccutyt4rlrDg',
#  'ssKa0PzIrsco8FB0hKQNWA',
#  'r8FdMPnNXHYoKEeR1rhEpw',
#  'r4qzH2FHPJnX7ooacHGpqA',
#  'S4Td7aFlG04gHLV3PsDrSg',
#  '-pKgWjj8jsLHPczNaAnaBA',
#  'k_Wo12Sq2S4GdbSocpRumg',
#  'ABjjIPgvdd58bBfM88qnwA',
#  'FXY6bj0GTWZoiA_uRng6xQ',
#  'MZ9-WvT6-gGMvKcr0ooZxw',
#  'QlOXTKJmfDthLMrkOtIU_w',
#  'WJxKe4MptIBI6sMUo_mB9Q',
#  'vBegFL1ZG_1v59cnN2t9AA',
#  '1G0zN-Y7BsX3KOXTLF47vg',
#  '8EbG-obwo_uuAmA9bKw0Dg',
#  '4k_gRAH7wxM3BbKZ-nIpUw',
#  'T38PudlpzBl8Pu46WmR5KA',
#  '5xg8O9rPksLss_I85tct-Q',
#  'XXuS66qQ8np3D3_j_7YMAQ',
#  'W7o8TeXrHnB5ydP5bomljQ',
#  'UWp92Ie7MhyjhDHObeTscQ',
#  'Hb_PMhy4nqXSpodqwAhrBw',
#  'CDm6meixtFeyyLrmes6OUg',
#  'EcaLLTjg6mzLbAp-eJmMeQ',
#  '7r7lK2yR2IOxNRrufe0RDw',
#  'ADxHLH2Fcx_ssPSK07_v6Q',
#  'L6httoOfEh05HL5mIprVeA',
#  'tF1fCwRnUqjMnpQDLye2ww',
#  'Z0dhlebl8VaK5zsSwedyOA',
#  'fRX5hUXX5xVjQ6tSy4h5iw',
#  'Lu9eupGCxJgx_t3yV2sWUg',
#  'Ta32HIzi_s_s0yXbldm-nA',
#  'iS7uaaRC5UksfXdLQv8GcQ',
#  'OckWqnU3Vpvka8quNhhxMg',
#  'ItsZJuwuEkFG6hLzGuzivg',
#  'TgOQ8SzYBdN9F0WoFRvcWw',
#  '66VgRlZVpgXvzulOQmHrHg',
#  'ikCkgJWNtfPwTRCBnocmyw',
#  'yGpVxscoFR0Z51ERu3dz2w',
#  'I24Pn-0p64R8lGD9NdA98g',
#  'FuVW_Bc9A3EpwRlAn5cOyA',
#  '9mP0nNQ7b6qJB9aXtVPTDw',
#  'Sm4C6lmKSWb56ELSQkvP9g',
#  'CAhiejtTE2sJAVGbQpdiFA',
#  'cK1HE5LbwLxtZbfHC_a3oQ',
#  'I-Yk8nKTiG093jqRo02QOg',
#  'ZCDi19pcOQnM0L6tPhPwcw',
#  'X0zmWe-YD11KF3Yd4JHlOQ',
#  'Ft43cJ-6M9BEJfNiYwfH2Q',
#  'c9hxkYInFnbtEsMob9baUg',
#  'wOIsEjf89DMFxx_zbtbnvA',
#  '1wSDQwtIDkjRF7zZmmAUMQ',
#  'D04cZA4yUmM0VTdmM6dN3w',
#  'OcZvEbjudxPdlRdmFx-QSA',
#  '0ZALznxqJpE4FyhIIPOITg',
#  '8czG5x2jvOvxuF3_IK4CoQ',
#  'BrBJd7U-KwBVmQQ4ocmCYw',
#  '5Yl1FEJoyz_lysHvgC0U4w',
#  '4lqV-rJnrw0Go1049DPjsA',
#  'aj8INKXp8ZdnsxC9FfEVeg',
#  'KPK0Tsr7_mIZJmuVIMIXGg',
#  'ipMPf_LH6pUAautoGEj3MQ',
#  'fR-voyYWs3U2q28UYrTlVg',
#  'PKCKLQHKZpetiPYXQf6XFg',
#  'AcXnPfDlGfHRc966G1-BqQ',
#  'HNDB6A0yXJvkPd4uVASnVQ',
#  'OMEZ0vu1tB8ilwNbNkBSUQ',
#  'jrv5hxKJxWQQssHq2k58LQ',
#  'D-Yf58g7ZqYucgja1TUdVQ',
#  'FLvAk3LSz57-jqzCFwxh3g',
#  'PfL8JuBKy7Yd3khoWFNhQg',
#  'qY65wCQABsdUJcm-DPyq8g',
#  'NFFxJQHNaq2_MFLzN5EZMQ',
#  'ibz7ono-grfmaYVhZmxP0A',
#  'R-iAej0oYo7IvfbUBLS0Uw',
#  'KyMDPAPSBciO6cCtsEBXNg',
#  '20dcMWU65FpczwZjYkqF7Q',
#  '9mNXjexhq4OjOiyOYoV67A',
#  '_NvNEbQpyCPGs5CswhZsfw',
#  'u6wZ5dU5CmvLyevgfreyJw',
#  'AXnerw4iD-Konye6M89tEQ',
#  'JgwKfDXQk98P9ynkJxU9Iw',
#  'RbNfbSTdfmLvDE5tYBZOsw',
#  'lbkIGoU9Cb5MYpVvQHRgkA',
#  'b4Ylosj5CHyKRtTxvJxIwA',
#  'rc6ZkTxIpBWl8vZO8i5UDg',
#  'S_ZkBgavh2_1O38w05U4pA',
#  '4d9UENLYmmOjUSj6zADmJA',
#  'UeUQqyjgbiXIfXwkh3NRjg',
#  '71daQ6tJLC_XxsqhS-dbKw',
#  '1WRc0v-JJxaok2WMMgA7Eg',
#  'AVii84Yaj5j-AlWpLWqj1Q',
#  'eRa_cqc9RyggzjT6Psiemw',
#  'xo_53Ec0MacJEC5ux7dWhQ',
#  'ZV6vNknY-IJi-JriyINEVQ',
#  '0mlr4gMU1C80xQh8FZ-uqg',
#  '7Fi61ncAOLfqcdWjj24w4Q',
#  'xv-4PaqiZ6Lt4h_AlAbEgQ',
#  '7pG-z5Yp93eNWvxgvVgVpQ',
#  'f0ofw94fI2JygnIr305CNA',
#  'h9B-VivFS_8BRX7MKF1bJw',
#  '9LnWXhTHZoai5azkl-ikig',
#  'zTyYQSg4k-7SC1IlNKcnGA',
#  'N-kiKG_FR2jXwpue-UO2XQ',
#  '1m4wZlhpGsg57oWLYfpcUA',
#  'rOoX7_slKOOUzrJVjMIvCA',
#  '4-fSplSdN9m4nWYGhEzNAw',
#  'PDjWNHSSWaBFgzBwHcOShg',
#  'yg1TX81xadEZsKvpwjZAGQ',
#  'B5G1gB-kHyENQItf-sF7sg',
#  'sR_od2KqmI4A6rFx-wLb0A',
#  'eMlbxj-AQXn_fRahnmQNOQ',
#  'v9Jq1eBWb7i5YIm0Jd76fg',
#  'UKZQXK4DfKnrZIW2wKwIag',
#  '2MaTZeukkrRPiL0vd9df4Q',
#  '7wuc02Ak3r4X-_QUn3GjhA',
#  'rS2V2_n5pPgBUJPHFfm9Pw',
#  'dmgM79l1qLnRWYwSBE48lw',
#  'VlvAvCFIYa7ISpXXbSxQXQ',
#  'bL4GlkwCS8EIm8ZM3hhlyg',
#  'BPrMpd6Wm8MRByakiiGsAg',
#  'lJzkTTMMEc7-siv7KX1r1A',
#  'yr42_FZkszoM8nwN6KjU7A',
#  'GRbtOxII1H_WhNMlOxyLJg',
#  'u4_Cb_7xkkn5Q56x_3FEBQ',
#  'E7F3GrkDOLRTF78QEzjJcg',
#  'K7bo_lWbA-BMxRNqehD7Pw',
#  'Iaao5TLesPU4aths0GNCOA',
#  'VCoP5KAhYVUOtyCpHd22jA',
#  'iFBQavf9kvcxPqXgmfTo4w',
#  '0W6J3j7Rqygj3e2Z4LoAJw',
#  'l1gJuDUXH3erEKKuXMELkA',
#  '8PD22MS_ZG6ft9eqQXbjYg',
#  'doyMZoah94iD3L9i7rqp-Q',
#  'BjYk_Do5cIxm6l0hlc7UUw',
#  'hkoEUM-isVJMvliuaprLHQ',
#  'fzVcNUX8pGubdmpBHvUNqQ',
#  'hFGw70MEv4P1NqU6DIA5xg',
#  'PMM7K1_oLUN4g3oj2fYHLQ',
#  'k-HbkcALZ-_ENNWGp1JUCA',
#  'DgwRMwrdsfaXDHWoB0E6FA',
#  'FdmOBlTa5FUZgr-6mMRYWw',
#  '0jyRpZWeuAQQVVdXHq7n5Q',
#  'CN3BLZwfG4eqZjvKrIZoAg',
#  'S_SezIzI6iEWlNk9UV48uA',
#  'dxiaBw0r4B2FFxf6tLLSFg',
#  'rZq9zWgd5Yh9K1KU0bJrmw',
#  'wtu-3M5UuXrM_0xVptCQAA',
#  'kdAhfzKndTjBZZbDaz9CMw',
#  'l5Gl0r98w4s1cIkkLDAojg',
#  'mgkF33BgKpjsKn1uzUyTww',
#  'nR6wsc5ld4bx6NTa0ogDwQ',
#  '8E4axw7ZyXtsie2F1JNnpQ',
#  'YIM474H1iuTfGbMtL-YXAw',
#  'HgJqVPLNI29YJIlYBmScQQ',
#  'H-eGWb6vngbBBmRyTC4C1A',
#  'njBcgf7fB68v8xm7tMPhXw',
#  'YJ2AjKFrOHgdM0i1usdJIA',
#  'xS-DhHufFHSFeBnF0Ghf6w',
#  'IiJP9wxsnJBzUGLJKavHag',
#  'Wz2eHvL0IVeAEtItGS3aGQ',
#  'O8lT8Qsp5fbwBg_O3xeEWg',
#  'Kd9Gw917jtLcB-l_kqQ21A',
#  'Z9aS4ejfV2W-pBuuB-7MDw',
#  'aZ_fn0jRXuJIRO8sb48e_Q',
#  'TUzzuSeIyK-4jCn7r5Tprg',
#  '-r89taISwsi4-vrFzxqb2Q',
#  '65Jo86t9CrTPtfo_MXA23g',
#  'MsX_9YcpQkVr0pE0yGmejw',
#  'A7_M0yYFqfyiy8XJwCWnkg',
#  'PoX-T9LjsNB_wwyfrTPQ5Q',
#  '89S3GDI0I5ZYa8B2GiQgKg',
#  'zhKTy6XLKkConDapIN11KA',
#  'x-0RTqIVQPkT0FM_JlODHg',
#  'ooW25TmTMFqXarTsCCNMSg',
#  'pnI8n8NJXmN2liyssX-p3A',
#  'ASlmYm1W1IS3Zx3MBELa2A',
#  'GA2vnY1hyXTIKVXOmkXa5Q',
#  '6lggRmNW4zjJGo4KnFZw0A',
#  'vmU5ZSENqImms-sMinyGWQ',
#  'D6u1NnDwoIVkGaWfDnxHiA',
#  'E5L6XNDnC2YkGVUO-HuEng',
#  'TgYR_KVE0JTUnEgE6D7Kcg',
#  'bb1go2qo20vsOX2wELXCNg',
#  'NHiY59H0CYlrDrovQLUcLw',
#  'PDxg5cJZPyUzU4zHL-5eMA',
#  'awNzV6YPQKyLsvg_4EfUqQ',
#  '7zRTV8lFEFgO3mHol1nrCw',
#  '9Jk2NZv58bYmoxuuKUD9TQ',
#  'Lv_ESYDy7FfX17VrpA2tQA',
#  '_lVdg7Tdw-Vkn0dn-gS2qw',
#  'ILYhl0cu38IEtZNY_JfZrw',
#  'oYFUHj8XFM36SdPCoQaXPQ',
#  'jbD3a2F4GfYqXllJdgt_yg',
#  'bD_pIC9BvLJx0XMJSXuE2Q',
#  'uQBpvekquAbioiHNxaPTHw',
#  'h1TkuhYSSdyTwa7FJJj3yg',
#  'fPnBu-W0-Mcpq2ljfu7OpA',
#  'exKjpnTtF9GMfqdzQC4XlA',
#  'ufz94E6pYIKrtWv9P4zZNw',
#  'oJYo0mAzlasXiOnJ5UPEHQ',
#  'I5tXvU7xf4Og26RIXdclTw',
#  'Fmei46LMZP00dQ3EuTx7kg',
#  'gMwFWxyHCG0L8CYvHPy_zQ',
#  'Ovk7r6zq6ExLJvj8sGN1BA',
#  'IuahnLr9Hk3KDHXnRxDRFQ',
#  'RDkWxO58Pk6IbElHw3kLTg',
#  'Lllv4pB7K2xPCNpK2x0dlg',
#  '8OLGO61TdpRpP-qgPYs2pw',
#  'Dht5tuQpI9m1DCuNG323xg',
#  'zLcAMGby3v9bafpKGh4ZjQ',
#  'whzPUXp9uc4Eue5r-mhmnQ',
#  'yadRI7SbvCHjSpHkSULeZw',
#  'FJyPWchWCcYBTKUPItL7dg',
#  'jt6YF8q-FctcxphgNwn1pg',
#  'cLR8tkBJF2SQoBb7c_U08g',
#  'UuBTMLnxT2TJD9Z3NGM8nA',
#  'eYKUr3IxC6tjyik9hq-Qvg',
#  'ImkIJxytVlekPalZdyBkJw',
#  '74A1HOz3ckwxlZDzcny0Sg',
#  'fRb_-mQiCaAfASrUgdK5Rg',
#  'QXcayVic6ds0myxIh5UrvA',
#  'TKOKsxlHU0n58Il6Mu8xLQ',
#  'lEbBEyn0cxVzXvfgFBS6Ag',
#  'yp1SfExew0mmX-MUmCMn-g',
#  'za9bTGNGL5AEOjorUKH_3Q',
#  '41qMqSKnnVu9uqIfhJi9aA',
#  'u12xq-qiqsfrQc-wi84AKA',
#  'b5hUQAkmFnJxYKaVZ_SNUA',
#  'LpwBUhgwW-NUFl1nINHfFA',
#  'zV1GhismnMryCtm3QsCpgw',
#  'nPzHSIaRnV0c6-kyudVHXQ',
#  'I0C8HvraosuTo2lRPjOedA',
#  'yfthQJ9I7G8Hli4weAHRAg',
#  'xIviYw8JevwWCTvUIYEdvQ',
#  '6N1TwiWWC0W8Bu5yjUxwUA',
#  'fjyuhEM-87FrPZ53zgDbXg',
#  'qaZ7I8vVgtKsF9L9AGmMBQ',
#  'krBpN5vbCQrB54QvTXOzaA',
#  'mfoNUZf1vrGUMF9oX6a4zQ',
#  'RbnkNLPBWDj2qYKPz8KIeA',
#  'aUluscKiuPmd8L2K7-FvyA',
#  'ZEoUP3Vz8zjIOPYfIy0qxg',
#  'KVHDStrweYbWeEI9vEQ8jg',
#  'CF6fr67K5TL9gXMx-CoGTw',
#  'QPTG5BWEW6ReFtOI-4X3QQ',
#  'Cdo_4-Uq0uTWTlp2DKLXrQ',
#  'q_1SYmd72ntns8d76YHAeQ',
#  '3stT022u8m1H37mcopGuUA',
#  'IPhzdHXgGWcFgFFT7RhQgQ',
#  'pr-YqG2g2UlI7u8VcVexhA',
#  'W0Gqu1L55LX5VvaP8MI8hA',
#  'cM2fhJhL6CU-AaZiqAAfzQ',
#  '7jV410giMcbmbxSaA_eihQ',
#  'oCbk_T5eyc3KB0iT6T5q9w',
#  '_iYo0zu3p62fssOzWcHD0w',
#  '2EcEsmpxAOXBBtH9kGVSaA',
#  'kxWXPgJY4BiVr8g9acgXrg',
#  'KXayc2FS7EfjeGhjO34ixw',
#  'KJqCJUxjoQECJN8ffFvx4w',
#  'GUI5Xsgy6E_-ltDQ62Ktew',
#  '-NQH6DmtwHzxJ_m4vJUfew',
#  '27hLpYF0Lb9TMuj_jtY0Ww',
#  'CEKhwiJvjYr0m7qVGVQY8g',
#  'lCaf-3791_1zYtVatfn0yA',
#  'VkEm3wUoi00GggTxVd6Aww',
#  'o1I9tQ37WWsPHTus5L82Ag',
#  'oayAictcR4pOJQakG6d0XQ',
#  'IvXkFTUxus5UhSOJrU23YA',
#  'pm36bCxGC_hPkLMhiObBDw',
#  'SH3mLia3JdfRfuU2EZHuQQ',
#  'OpPXqUdMR_PKxvvpaRZAwQ',
#  'vM3-LRIDgPBIeJ8lOgLbrg',
#  'Y3RWin2ub4TwGaKAonFy3A',
#  'HCB7mrfM1iBmO-Eizl-BGA',
#  'uCE1n9Ea6E-TEElqNormcg',
#  '34kCRaTxtLA6iyQVTYOBTA',
#  'EBrdbQKyptZJcZTt7m-phg',
#  '6Hs-lzX4xCx2weetcuT6JA',
#  'uHgw8kL3a3WkQhcg8gnv_w',
#  'vachj6CuyVSaxAP_qy79jw',
#  'HZANmX2YVRnBfVV6SBu-Ug',
#  'Iyorx13bB_kullO52xFpOA',
#  '4SvR-3c2edW0dgaqBpu6jg',
#  '-jfUzBSkFc4bxTOoi2BViA',
#  'orq3TAwiKAQmE2M300UY3A',
#  'hA0e3v7ceuFCJUa5S2JYoQ',
#  'vYda9v7iRAx5zNBHsLeezg',
#  'PkQpJAPvBYSVu81gTF6KWA',
#  'remsoXeBut5W6ibvpM40cA',
#  'bwFhSWf43ziTaGMKVsuv8g',
#  'tc3f6FZnjA4AIyrQoppVFg',
#  'UOPLTk8rFclrEArVfupXiQ',
#  '7BIH7ga7YotCM_Bh6qplIA',
#  'hifoN6UwnOU-GmAnF87pEQ',
#  'gDcKAJwdpIi4NKQI0QVBCQ',
#  'meZwZYmsOct3VxW4PKTAFg',
#  '0oOgp4PvMglkTYuZf1oI4w',
#  'uPo3vL_fOIV6QYn-650BGQ',
#  '8-GkE9JUtXjLJHgYXmx3Yg',
#  'g7hXPt-XEJET7aTJxh_Xew',
#  'wSi_ZrZLVWS1TSDfETTrCA',
#  'gDmcQrxfHdmU4UUOXnhWbQ',
#  '3r8kNyiBiaSQTQGfMztv0w',
#  'Dy9fTTBNaIVNGbKh_ycH7g',
#  'AhnLQ2Uf-rbduYy0NEFkjw',
#  '67u8qrpAwrgO7EEWM8OzNA',
#  'q9gSbV-hY0O7eIs--O2AfA',
#  'xV7Oe6ZE56qDVJ8NqSLJuQ',
#  'h-JSVmjhz1DRrof_M66AEA',
#  '0-nfZsIDDNXnlMN7qSRh5Q',
#  't_VsrUZjQp-d7f-ix-0SeQ',
#  'YJkJZkWXOv0WsJI2u-T9uA',
#  'XDEoW3CfiDgFKnrTEFTQJQ',
#  'FQziJtb-cJ-EKIdsEpTLPg',
#  '8WYIG5N1tWsRtjL6DpZxqQ',
#  'J1poq215-JQFCSrFfUN4ZA',
#  'VyZuyPnFMVoK_1w-UGqAqQ',
#  'IWDAWWrKhH_RQJPe47a4jQ',
#  'VpU8gUZUWd6mleMHGekf4Q',
#  'mgv_2irNc-FwWGCU104d0g',
#  'kgtom8IlghsvW6SwywhrwQ',
#  '8vu01wz2w8eUVidxvXMgfQ',
#  'mntX7UW04AhpDCqpRZWpQA',
# Querying https://api.yelp.com/v3/businesses/FQziJtb-cJ-EKIdsEpTLPg ...
# Querying https://api.yelp.com/v3/businesses/8WYIG5N1tWsRtjL6DpZxqQ ...
# Querying https://api.yelp.com/v3/businesses/J1poq215-JQFCSrFfUN4ZA ...
# Querying https://api.yelp.com/v3/businesses/VyZuyPnFMVoK_1w-UGqAqQ ...
# Querying https://api.yelp.com/v3/businesses/IWDAWWrKhH_RQJPe47a4jQ ...
# Querying https://api.yelp.com/v3/businesses/VpU8gUZUWd6mleMHGekf4Q ...
# Querying https://api.yelp.com/v3/businesses/mgv_2irNc-FwWGCU104d0g ...
# Querying https://api.yelp.com/v3/businesses/kgtom8IlghsvW6SwywhrwQ ...
# Querying https://api.yelp.com/v3/businesses/8vu01wz2w8eUVidxvXMgfQ ...
# Querying https://api.yelp.com/v3/businesses/mntX7UW04AhpDCqpRZWpQA ...
# Querying https://api.yelp.com/v3/businesses/XlRGtOjPuiEfZsKuo2fRdw ...

# %%
alias_to_title["appraisalservices"]
# Out:
# 'Appraisal Services'

# %%
len(list(filter(lambda x: "categories" not in x or x["categories"] == [], augment_business.values())))
# Out:
# 360

# %%
import json

with open("../../yelp_dataset/augment_business.json", "w") as f:
    f.write(json.dumps(augment_business, indent=0))

# %%
count_ = 0
for bid in augment_business:
    if "name" not in augment_business[bid]:
        count_ += 1
        continue
        
    name = augment_business[bid]["name"]
    count = df_selected_meta.filter(col("name") == name).count()
    if count <= 1:
        count_ += 1
print(count_)
# Out:
# 377

# %%
df_selected_meta.filter(col("city") == "Fairview Park").count()
# Out:
# 106

# %%
city_count = df_filtered.groupBy("state", "top_category").agg(F.count("*").alias("count"))

# %%
city_count.show()
# Out:
# DataFrame[state: string, top_category: string, count: bigint]

# %%
from pyspark.sql.functions import *
from pyspark.sql.window import Window

city_count.withColumn("rank", rank().over(Window.orderBy(asc("count")))).show(100)
# Out:
# +-----+--------------------+-----+----+
# |state|        top_category|count|rank|
# +-----+--------------------+-----+----+
# |   VT|Event Planning & ...|    1|   1|
# |   CA|        Local Flavor|    1|   1|
# |   AL|    Health & Medical|    1|   1|
# |   TX|         Restaurants|    1|   1|
# |   FL|          Automotive|    1|   1|
# |   CA|                Pets|    1|   1|
# |  XWY|         Restaurants|    1|   1|
# |   NY|       Beauty & Spas|    1|   1|
# |   AK|           Education|    1|   1|
# |   FL|     Hotels & Travel|    1|   1|
# |   TN|       Home Services|    1|   1|
# |   WA|       Home Services|    1|   1|
# |   TX|Professional Serv...|    1|   1|
# |  BAS|                Food|    1|   1|
# |   GA|      Local Services|    1|   1|
# |  CON|         Restaurants|    1|   1|
# |  DUR|Professional Serv...|    1|   1|
# |   BC|         Restaurants|    1|   1|
# |   TX|            Shopping|    1|   1|
# |   VT|       Home Services|    1|   1|
# |   GA|       Home Services|    1|   1|
# |  XGM|       Home Services|    1|   1|
# |   AK|           Nightlife|    1|   1|
# |  XWY|                Food|    1|   1|
# |   IL|Religious Organiz...|    1|   1|
# |   VA|Event Planning & ...|    1|   1|
# |   NM|                Food|    1|   1|
# |  XGL|                Food|    1|   1|
# |   NY|    Health & Medical|    1|   1|
# |   AR|                Food|    1|   1|
# |   NE|Professional Serv...|    1|   1|
# |   NJ|                Pets|    1|   1|
# |   NY|      Local Services|    1|   1|
# |   TX|       Home Services|    1|   1|
# |   VA|       Beauty & Spas|    1|   1|
# |   CT|          Automotive|    1|   1|
# |   CA|    Health & Medical|    1|   1|
# |   NY|Professional Serv...|    1|   1|
# |   UT|       Home Services|    1|   1|
# |   WA|                Food|    1|   1|
# |   FL|  Financial Services|    1|   1|
# |   FL|         Restaurants|    1|   1|
# |  XGM|            Shopping|    1|   1|
# |   NY|       Home Services|    1|   1|
# |   NE|                Food|    1|   1|
# |  XGM|         Restaurants|    1|   1|
# |  XGM|                Food|    1|   1|
# |   CA|      Local Services|    1|   1|
# |  DOW|Arts & Entertainment|    1|   1|
# |   WA|            Shopping|    1|   1|
# |   CA|Professional Serv...|    2|  51|
# |   AL|                Food|    2|  51|
# |   NY|Event Planning & ...|    2|  51|
# |   TX|       Beauty & Spas|    2|  51|
# |   NY|            Shopping|    2|  51|
# |   CT|            Shopping|    2|  51|
# |   SC|            NotFound|    3|  57|
# |   CA|       Home Services|    3|  57|
# |   SC|Religious Organiz...|    3|  57|
# |   CA|Event Planning & ...|    4|  60|
# |   QC|          Mass Media|    4|  60|
# |   AB|Religious Organiz...|    4|  60|
# |   QC|Religious Organiz...|    5|  63|
# |   IL|            NotFound|    5|  63|
# |   IL|          Mass Media|    5|  63|
# |   WI|Religious Organiz...|    5|  63|
# |   CA|       Beauty & Spas|    6|  67|
# |   SC|     Hotels & Travel|    6|  67|
# |   SC|  Financial Services|    6|  67|
# |   SC|           Nightlife|    6|  67|
# |   SC|Public Services &...|    6|  67|
# |   NY|                Food|    6|  67|
# |   WI|            NotFound|    7|  73|
# |   NY|         Restaurants|    7|  73|
# |   WI|          Mass Media|    8|  75|
# |   OH|          Mass Media|    8|  75|
# |   ON|Religious Organiz...|    8|  75|
# |   SC|        Local Flavor|    8|  75|
# |   AB|          Mass Media|   11|  79|
# |   QC|  Financial Services|   11|  79|
# |   PA|          Mass Media|   11|  79|
# |   SC|           Education|   12|  82|
# |   NC|          Mass Media|   14|  83|
# |   AB|            NotFound|   14|  83|
# |   IL|Public Services &...|   14|  83|
# |   IL|        Local Flavor|   15|  86|
# |   IL|  Financial Services|   15|  86|
# |   SC|Arts & Entertainment|   17|  88|
# |   ON|          Mass Media|   17|  88|
# |   IL|           Education|   17|  88|
# |   PA|            NotFound|   19|  91|
# |   QC|Public Services &...|   21|  92|
# |   OH|Religious Organiz...|   21|  92|
# |   SC|Professional Serv...|   24|  94|
# |   IL|     Hotels & Travel|   26|  95|
# |   PA|Religious Organiz...|   29|  96|
# |   QC|            NotFound|   30|  97|
# |   OH|            NotFound|   32|  98|
# |   WI|     Hotels & Travel|   34|  99|
# |   QC|Professional Serv...|   34|  99|
# +-----+--------------------+-----+----+
# only showing top 100 rows

# %%
city_count.filter(col("count") <= 100).count()
# Out:
# 1074

# %%
city_count.count()
# Out:
# 301
