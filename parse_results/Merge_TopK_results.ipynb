# %%
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("../")

# %%
from src.utility.Summary import Summary

# %%
side_info_params = {
    "CollectiveMF_Item": {"use_user_info": False, "use_item_info": True},
    "CollectiveMF_User": {"use_user_info": True, "use_item_info": False},
    "CollectiveMF_Both": {"use_user_info": True, "use_item_info": True},
    "CollectiveMF_No": {"use_user_info": False, "use_item_info": False},
}

# %%
model_with_params = []
for db_path in ["default_server.db", "new_server.db"]:
    summary = Summary(db_path="sqlite:///" + db_path)
    for model in list(side_info_params.keys()) + ["surprise_SVD", "surprise_Baseline", "FMItem", "FMNone", "BPR","PureRandom"]:
        opt = summary.get_optimal_params(dataset_name="user_10_item_1_exp", model_name=model, metric="ndcg@10")
        if not opt: continue
        params_dict = dict(eval(opt))

        model_with_params.append((model, params_dict))
# Out:
# Best ndcg@10 of CollectiveMF_Item is found as 0.13918122178525763
# Best ndcg@10 of CollectiveMF_User is found as 0.13722715694739976
# Best ndcg@10 of CollectiveMF_Both is found as 0.17519375060900866
# Best ndcg@10 of CollectiveMF_No is found as 0.13959638505198083
# Best ndcg@10 of surprise_SVD is found as 0.08947580881252634
# Best ndcg@10 of surprise_Baseline is found as 0.09295524312705676
# Best ndcg@10 of PureRandom is found as 0.02336825218484509
# Best ndcg@10 of FMItem is found as 0.049514178125419
# Best ndcg@10 of FMNone is found as 0.053887441376631894
# Best ndcg@10 of BPR is found as 0.16738308198769195

# %%
df_list = []
for db_path in ["default_server.db", "new_server.db"]:
    summary = Summary(db_path="sqlite:///" + db_path)
    for model, opt_param in model_with_params:
        for metric in ["ndcg@{}".format(k+1) for k in range(10)]:
            str_param = str(sorted(opt_param.items(), key=lambda x: x[0]))
            
            df = summary.get_result_for_params(dataset_name="user_10_item_1_exp", model_name=model, 
                                           hyper=str_param, metric=metric, verbose=False)
            if len(df) == 0: continue
            df_list.append(df)

# %%
topk_results = pd.concat(df_list).reset_index(drop=True)

# %%
topk_results["k"] = topk_results.metric.apply(lambda x: int(x.split("@")[1]))

# %%
topk_results
# Out:
#                 model                                              hyper  \
# 0   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 1   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 2   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 3   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 4   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 5   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 6   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 7   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 8   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 9   CollectiveMF_Item  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 10  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 11  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 12  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 13  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 14  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 15  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 16  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 17  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 18  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 19  CollectiveMF_User  [('k', 16), ('reg_param', 0.01), ('w_main', 0.5)]
# 20  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# 21  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# 22  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# 23  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# 24  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# 25  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# 26  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# 27  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# 28  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# 29  CollectiveMF_Both   [('k', 4), ('reg_param', 0.01), ('w_main', 1.0)]
# ..                ...                                                ...
# 70             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 71             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 72             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 73             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 74             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 75             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 76             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 77             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 78             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 79             FMItem  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 80             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 81             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 82             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 83             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 84             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 85             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 86             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 87             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 88             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 89             FMNone  [('l2_reg_V', 1), ('l2_reg_w', 1), ('model_inf...
# 90                BPR  [('factors', 16), ('iteration', 100), ('learni...
# 91                BPR  [('factors', 16), ('iteration', 100), ('learni...
# 92                BPR  [('factors', 16), ('iteration', 100), ('learni...
# 93                BPR  [('factors', 16), ('iteration', 100), ('learni...
# 94                BPR  [('factors', 16), ('iteration', 100), ('learni...
# 95                BPR  [('factors', 16), ('iteration', 100), ('learni...
# 96                BPR  [('factors', 16), ('iteration', 100), ('learni...
# 97                BPR  [('factors', 16), ('iteration', 100), ('learni...
# 98                BPR  [('factors', 16), ('iteration', 100), ('learni...
# 99                BPR  [('factors', 16), ('iteration', 100), ('learni...
#
#      metric     value                         ts   k
# 0    ndcg@1  0.055422 2019-12-18 01:32:20.734647   1
# 1    ndcg@2  0.078422 2019-12-18 01:32:38.024594   2
# 2    ndcg@3  0.092794 2019-12-18 01:32:55.187776   3
# 3    ndcg@4  0.103548 2019-12-18 01:33:12.001429   4
# 4    ndcg@5  0.112015 2019-12-18 01:33:29.350053   5
# 5    ndcg@6  0.119114 2019-12-18 01:33:48.561930   6
# 6    ndcg@7  0.125053 2019-12-18 01:34:05.818648   7
# 7    ndcg@8  0.130339 2019-12-18 01:34:22.674496   8
# 8    ndcg@9  0.134955 2019-12-18 01:34:39.886431   9
